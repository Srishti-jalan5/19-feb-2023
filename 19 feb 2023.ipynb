# %%
Q1
Flask is a widely used micro web framework for creating APIs in Python. It is a simple yet powerful 
web framework that is designed to get started quickly and easily.

ADvantage - Lightweight,Easy to use,scalable and flexible.
2.Support secure cookies.
3.Offers a built-in development server and fast debugger.

# %% [markdown]
# ![image.png](attachment:a6e909b0-9d02-45c6-8c60-213ae89c7d3b.png)

# %%
Q3
App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
We use App route to access the specific function from millions of methods by entering your need. 
example searching for a specific music.

# %% [markdown]
# Q4
# ![image.png](attachment:b4a1532a-5620-4531-97de-afb6e1d5f035.png)

# %% [markdown]
# ![image.png](attachment:6e82ebdc-cbbf-4608-b237-7a0fc264d26c.png)

# %%
Q5
The url_for() method is used to prepare a URL for a function dynamically.
